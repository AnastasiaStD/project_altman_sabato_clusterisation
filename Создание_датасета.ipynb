# %% [markdown]
# # Импорт необходимых библиотек

# %%
#Импортируем необходимые библиотеки

import math
import numpy as np # Линейная алгебра и многомерные массивы
import pandas as pd # Работа с таблицами данных
import matplotlib.pyplot as plt # Графическая библиотека
from ipywidgets import widgets, interact # Интерактивные виджеты

# Техническая функция. Иногда потребуется сравнивать два float числа на равенство
def is_equal(x, y):
    return abs(x-y) < 1e-6

# %% [markdown]
# # Выгрузка необходимых данных

# %%
df1 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1127.xlsx")
df2 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1128 (1).xlsx")
df3 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1128.xlsx")
df4 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1129 (1).xlsx")
df5 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1129.xlsx")
df6 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1130.xlsx")
df7 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1131.xlsx")
df8 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1132 (1).xlsx")
df9 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1132.xlsx")
df10 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1133.xlsx")
df11 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1134.xlsx")
df12 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1145 (1).xlsx")
df13 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1145.xlsx")
df14 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1146.xlsx")
df15 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1147.xlsx")
df16 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1148.xlsx")
df17 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1149 (1).xlsx")
df18 = pd.read_excel("/content/drive/MyDrive/ИПС/Данные/СПАРК_Выборка_компаний_20240126_1149.xlsx")

# %%
df1.shape[0]
# Out:
# 9531

# %%
l = 0

num_rows = df1.shape[0]
df1 = df1.drop(index=[num_rows - 1, num_rows - 2])
df1 = df1.drop(df1.columns[0], axis=1)
l = l + df1.shape[0]


num_rows = df2.shape[0]
df2 = df2.drop(index=[num_rows - 1, num_rows - 2])
df2 = df2.drop(df2.columns[0], axis=1)
l = l + df2.shape[0]


num_rows = df3.shape[0]
df3 = df3.drop(index=[num_rows - 1, num_rows - 2])
df3 = df3.drop(df3.columns[0], axis=1)
l = l + df3.shape[0]


num_rows = df4.shape[0]
df4 = df4.drop(index=[num_rows - 1, num_rows - 2])
df4 = df4.drop(df4.columns[0], axis=1)
l = l + df4.shape[0]


num_rows = df5.shape[0]
df5 = df5.drop(index=[num_rows - 1, num_rows - 2])
df5 = df5.drop(df1.columns[0], axis=1)
l = l + df5.shape[0]


num_rows = df6.shape[0]
df6 = df6.drop(index=[num_rows - 1, num_rows - 2])
df6 = df6.drop(df6.columns[0], axis=1)
l = l + df6.shape[0]


num_rows = df7.shape[0]
df7 = df7.drop(index=[num_rows - 1, num_rows - 2])
df7 = df7.drop(df7.columns[0], axis=1)
l = l + df7.shape[0]


num_rows = df8.shape[0]
df8 = df8.drop(index=[num_rows - 1, num_rows - 2])
df8 = df8.drop(df8.columns[0], axis=1)
l = l + df8.shape[0]

num_rows = df9.shape[0]
df9 = df9.drop(index=[num_rows - 1, num_rows - 2])
df9 = df9.drop(df9.columns[0], axis=1)
l = l + df9.shape[0]


num_rows = df10.shape[0]
df10 = df10.drop(index=[num_rows - 1, num_rows - 2])
df10 = df10.drop(df10.columns[0], axis=1)
l = l + df10.shape[0]


num_rows = df11.shape[0]
df11 = df11.drop(index=[num_rows - 1, num_rows - 2])
df11 = df11.drop(df11.columns[0], axis=1)
l = l + df11.shape[0]


num_rows = df12.shape[0]
df12 = df12.drop(index=[num_rows - 1, num_rows - 2])
df12 = df12.drop(df12.columns[0], axis=1)
l = l + df12.shape[0]


num_rows = df13.shape[0]
df13 = df13.drop(index=[num_rows - 1, num_rows - 2])
df13 = df13.drop(df13.columns[0], axis=1)
l = l + df13.shape[0]


num_rows = df14.shape[0]
df14 = df14.drop(index=[num_rows - 1, num_rows - 2])
df14 = df14.drop(df14.columns[0], axis=1)
l = l + df14.shape[0]


num_rows = df15.shape[0]
df15 = df15.drop(index=[num_rows - 1, num_rows - 2])
df15 = df15.drop(df15.columns[0], axis=1)
l = l + df15.shape[0]


num_rows = df16.shape[0]
df16 = df16.drop(index=[num_rows - 1, num_rows - 2])
df16 = df16.drop(df16.columns[0], axis=1)
l = l + df16.shape[0]


num_rows = df17.shape[0]
df17 = df17.drop(index=[num_rows - 1, num_rows - 2])
df17 = df17.drop(df17.columns[0], axis=1)
l = l + df17.shape[0]


num_rows = df18.shape[0]
df18 = df18.drop(index=[num_rows - 1, num_rows - 2])
df18 = df18.drop(df18.columns[0], axis=1)
l = l + df18.shape[0]


data_frame = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18], ignore_index=True)
data_frame['index_column'] = data_frame.index


data_frame
# Out:
#                        Наименование  Регистрационный номер  \
# 0                 3-Е ИЮЛЯ, ООО РИФ           1.025701e+12
# 1             ПЕТРОСТРОЙИНВЕСТ, ООО           1.057812e+12
# 2                          ТЭМ, ООО           1.121831e+12
# 3              ЛАЙК ТЕХНОЛОГИИ, ООО           1.167847e+12
# 4                  ВАРЯГ-2, ООО ЧОП           1.047422e+12
# ...                             ...                    ...
# 160974      СТОКМАНН СПБ ЦЕНТР, ООО           1.057811e+12
# 160975                  СТАЛТА, ООО           1.076639e+12
# 160976                     МЭЩ, ООО           1.157747e+12
# 160977                  МАДРИД, ООО           1.072628e+12
# 160978  СИСТЕМЫ И ТЕХНОЛОГИИ, АО ГК           1.033303e+12
#
#        2018, Среднесписочная численность работников  \
# 0                                                 1
# 1                                                 1
# 2                                               NaN
# ...

# %%
data_frame.to_excel("/content/drive/MyDrive/ИПС/Данные/Итог.xlsx", index=False)
